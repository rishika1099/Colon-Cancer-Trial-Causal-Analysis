# %% [markdown]
# # Q2 — The bad-control demo
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** δ_HR conditional on M (recurrence). NOT an interpretable causal effect.
#
# **2×2 cell.** Pedagogical anti-example.
#
# **Identifying assumption (graphical).** Conditioning on M opens a collider path rx → M ← U → Y_death; blocks the rx → M → Y_death mediator path.
#
# **Identifying assumption (non-graphical).** M is post-treatment; sequential ignorability would be required to interpret δ as NDE.
#
# **Estimator.** Cox with rx + M + Z; show the attenuated coefficient on rx vs Q2_ipw.
#
# **Failure mode.** If the analyst stops here and interprets the rx coefficient as 'treatment effect,' they are wrong.
#
# **Target population.** n/a — the point is what NOT to estimate.
#
# **Naive-reader mistake.** Adjusting for everything 'predictive of outcome' including post-treatment variables.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
