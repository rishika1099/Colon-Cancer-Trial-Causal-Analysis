# %% [markdown]
# # Q2 — AIPW / DR for RMST
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** δ_RMST(5y) via doubly-robust augmented IPW.
#
# **2×2 cell.** Causal × no-selection (obs).
#
# **Identifying assumption (graphical).** Backdoor via Z.
#
# **Identifying assumption (non-graphical).** Either e(Z) OR outcome regression μ(Z, rx) is correctly specified.
#
# **Estimator.** Hand-coded AIPW for RMST OR econml DRLearner with RMST outcome.
#
# **Failure mode.** Both nuisances misspecified → no double-robustness protection.
#
# **Target population.** Same as Q1.
#
# **Naive-reader mistake.** Reporting AIPW point estimate without checking nuisance fit (cross-fit RMSE).
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
