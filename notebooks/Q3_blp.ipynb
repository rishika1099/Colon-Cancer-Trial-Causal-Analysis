# %% [markdown]
# # Q3 — Best linear projection of CATE
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** Best linear projection coefficients of τ(Z) onto a chosen Ψ(Z) (Semenova & Chernozhukov 2021).
#
# **2×2 cell.** Causal × no-selection (conditional).
#
# **Identifying assumption (graphical).** As Q3_causal_forest plus the standard BLP regularity conditions.
#
# **Identifying assumption (non-graphical).** Same as Q3 + correct specification of Ψ.
#
# **Estimator.** BLP from econml; report coefficients with HC0 CIs.
#
# **Failure mode.** BLP coefficients are projection summaries, not causal moderator effects.
#
# **Target population.** Same as Q1.
#
# **Naive-reader mistake.** Interpreting a BLP coefficient on, e.g., age, as 'older patients benefit more causally.'
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
