# %% [markdown]
# # Q3 — Feature importance
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** Forest-based variable importance for moderation.
#
# **2×2 cell.** Causal × no-selection (conditional).
#
# **Identifying assumption (graphical).** n/a — descriptive of the τ̂(z) function.
#
# **Identifying assumption (non-graphical).** n/a — descriptive of the τ̂(z) function.
#
# **Estimator.** econml causal-forest VI; SHAP on τ̂(z) surface.
#
# **Failure mode.** VI ≠ causal moderation. It is variable importance for predicting τ̂.
#
# **Target population.** Same as Q1.
#
# **Naive-reader mistake.** Concluding that a top-VI variable causally moderates without independent BLP/test.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
