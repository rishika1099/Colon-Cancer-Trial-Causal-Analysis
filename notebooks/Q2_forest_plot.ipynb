# %% [markdown]
# # Q2 — Five-estimator forest plot
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** δ_HR (or δ_RMST) from {naive Cox, IPW, AIPW, DML, bad-control}.
#
# **2×2 cell.** Causal × no-selection (obs) + the anti-example.
#
# **Identifying assumption (graphical).** All but bad-control identify via backdoor; bad-control does not identify.
#
# **Identifying assumption (non-graphical).** All but bad-control share the conditional exchangeability assumption.
#
# **Estimator.** Forest plot of point estimates + 95% CIs.
#
# **Failure mode.** If IPW/AIPW/DML disagree materially with the randomized Q1 answer, something is wrong with Z.
#
# **Target population.** Same as Q1.
#
# **Naive-reader mistake.** Looking at the forest and concluding 'methods don't matter' — bad-control breaks the convergence.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
