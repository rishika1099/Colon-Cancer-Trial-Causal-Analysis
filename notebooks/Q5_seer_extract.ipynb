# %% [markdown]
# # Q5 — SEER 1990 stage B/C extract
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** Marginal P(Z=z | S=0) — the target-population covariate distribution.
#
# **2×2 cell.** Pre-causal: data-engineering step.
#
# **Identifying assumption (graphical).** n/a — descriptive.
#
# **Identifying assumption (non-graphical).** n/a — descriptive.
#
# **Estimator.** SEER*Stat case-listing session, 1989-1991, colorectal, stage B/C; export to seer_1990.csv.
#
# **Failure mode.** SEER coding of stage differs from Astler-Coller used in Moertel.
#
# **Target population.** U.S. 1990 stage B/C resected colon-cancer patients.
#
# **Naive-reader mistake.** Assuming SEER covariates align 1-to-1 with trial covariates (they do not).
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
