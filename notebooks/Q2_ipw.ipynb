# %% [markdown]
# # Q2 — IPW Cox
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** δ_HR^IPW under backdoor adjustment.
#
# **2×2 cell.** Causal × no-selection (obs).
#
# **Identifying assumption (graphical).** Backdoor via Z; w = 1/e(Z) for treated, 1/(1-e(Z)) for control.
#
# **Identifying assumption (non-graphical).** Conditional exchangeability + positivity.
#
# **Estimator.** Stabilized IPW weights; weighted Cox via lifelines.
#
# **Failure mode.** Mis-specified e(Z) biases the weights; extreme weights inflate variance.
#
# **Target population.** Same as Q1.
#
# **Naive-reader mistake.** Forgetting variance inflation when reporting CIs from weighted regression.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
