# %% [markdown]
# # S2 — Master sensitivity table
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** Synthesis across all sensitivity analyses.
#
# **2×2 cell.** Sensitivity.
#
# **Identifying assumption (graphical).** Union of identifying assumptions across Q1–Q5.
#
# **Identifying assumption (non-graphical).** Union of non-graphical assumptions across Q1–Q5.
#
# **Estimator.** Single master table: estimand, point, 95% CI, sensitivity parameter, breakdown value, qualitative robustness.
#
# **Failure mode.** n/a — synthesis step.
#
# **Target population.** n/a — synthesis step.
#
# **Naive-reader mistake.** Reading robustness as binary; report it as a continuous breakdown value.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
