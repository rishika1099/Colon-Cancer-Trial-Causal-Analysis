# %% [markdown]
# # Q5 — Dahabreh worst-case bounds
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** Worst-case bound on δ_ATE^target under one unmeasured effect modifier (Dahabreh et al. 2019).
#
# **2×2 cell.** Causal × selection.
#
# **Identifying assumption (graphical).** Bounds on the unmeasured effect modifier's HR with rx.
#
# **Identifying assumption (non-graphical).** Bounded-effect-modifier sensitivity.
#
# **Estimator.** Sensitivity sweep; tipping point at which bound covers 0.
#
# **Failure mode.** If tipping point is implausibly small, finding is fragile.
#
# **Target population.** U.S. 1990 stage B/C resected CRC.
#
# **Naive-reader mistake.** Quoting the point estimate without the bound.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
