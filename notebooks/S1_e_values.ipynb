# %% [markdown]
# # S1 — E-values (VanderWeele 2017)
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** E-value for each causal point estimate.
#
# **2×2 cell.** Sensitivity.
#
# **Identifying assumption (graphical).** Unmeasured U on each of {Q1 HR, Q2 IPW HR, Q3 CATE summary, Q5 transported HR}.
#
# **Identifying assumption (non-graphical).** Bounded-U sensitivity per VanderWeele-Ding.
#
# **Estimator.** sensemakr (R) and direct E-value formulas.
#
# **Failure mode.** E-value mis-states sensitivity for time-varying U or non-rare outcomes.
#
# **Target population.** Same as the underlying estimate.
#
# **Naive-reader mistake.** Reading E-value as a hypothesis test rather than a sensitivity bound.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
