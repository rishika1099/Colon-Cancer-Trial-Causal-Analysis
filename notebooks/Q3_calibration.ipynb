# %% [markdown]
# # Q3 — Athey-Wager calibration
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** Bin patients by τ̂(z) quantile; compare observed vs predicted within-bin ATE.
#
# **2×2 cell.** Causal × no-selection (conditional).
#
# **Identifying assumption (graphical).** Quantile binning + within-bin randomization.
#
# **Identifying assumption (non-graphical).** Within-bin conditional exchangeability.
#
# **Estimator.** Athey-Wager calibration plot; binned within-bin AIPW.
#
# **Failure mode.** Poor calibration suggests overfitting or misspecification.
#
# **Target population.** Same as Q1.
#
# **Naive-reader mistake.** Skipping calibration and trusting τ̂(z) at face value.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
