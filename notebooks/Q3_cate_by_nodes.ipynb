# %% [markdown]
# # Q3 — CATE vs nodes (headline figure)
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** τ(nodes=k) for k = 0..max.
#
# **2×2 cell.** Causal × no-selection (conditional).
#
# **Identifying assumption (graphical).** Randomization within strata of nodes.
#
# **Identifying assumption (non-graphical).** Conditional exchangeability + positivity at each nodes value.
#
# **Estimator.** Causal forest projection onto nodes; scatter + ribbon.
#
# **Failure mode.** Few patients at high node counts → wide ribbons.
#
# **Target population.** Same as Q1.
#
# **Naive-reader mistake.** Reading peaks as significant moderation; reporting without CI ribbons.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
