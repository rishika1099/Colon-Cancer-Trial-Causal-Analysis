# %% [markdown]
# # Q5 — Transported ATE
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** δ_ATE^target = E_X|S=0[ τ(X) ].
#
# **2×2 cell.** Causal × selection.
#
# **Identifying assumption (graphical).** Same as Q5_iosw.
#
# **Identifying assumption (non-graphical).** Same as Q5_iosw.
#
# **Estimator.** Weighted Cox / RMST using w(X); compare to within-trial Q1.
#
# **Failure mode.** Transported estimate diverging from Q1 → effect modification by mismatch covariates.
#
# **Target population.** U.S. 1990 stage B/C resected CRC.
#
# **Naive-reader mistake.** Calling the transported estimate generalizable without bounding U_X.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
