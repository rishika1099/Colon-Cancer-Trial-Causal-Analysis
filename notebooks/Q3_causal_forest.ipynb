# %% [markdown]
# # Q3 — Causal forest (econml)
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** τ(z) via honest causal forest.
#
# **2×2 cell.** Causal × no-selection (conditional).
#
# **Identifying assumption (graphical).** Randomization within strata of Z.
#
# **Identifying assumption (non-graphical).** Conditional exchangeability + positivity + honesty (sample-splitting in tree).
#
# **Estimator.** econml.grf.CausalForest with honest=True, inference=True.
#
# **Failure mode.** Forest pointwise CIs are not jointly valid across z.
#
# **Target population.** Same as Q1.
#
# **Naive-reader mistake.** Treating the heatmap of τ̂(z) as if its peaks are statistically significant.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
