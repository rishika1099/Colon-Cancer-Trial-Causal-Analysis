# %% [markdown]
# # Q1 — PH diagnostic + subgroup forest
#
# ## Estimand-first header (per project rigor rule #2)
#
# **Estimand.** Same as Q1_ate; stratified estimands within node4 strata.
#
# **2×2 cell.** Causal × no-selection.
#
# **Identifying assumption (graphical).** Randomization within strata of node4.
#
# **Identifying assumption (non-graphical).** Conditional exchangeability holds within strata.
#
# **Estimator.** Schoenfeld residuals (global + per covariate); forest plot of stratum-specific HRs.
#
# **Failure mode.** Non-PH means the HR is a time-average; report RMST instead.
#
# **Target population.** Same as Q1.
#
# **Naive-reader mistake.** Treating a single HR as the effect when PH is violated.
#
# ---
#
# _Analysis cells follow in the corresponding week's build step._

# %%
import numpy as np
import pandas as pd
np.random.seed(42)

# Load primary analytic frame (etype==2: death-row records)
df = pd.read_csv('../data/colon.csv')
df_death = df[df['etype'] == 2].copy()
df_death.shape
